# %% [markdown]
# ### 단일 페이지로부터 데이터 수집하기

# %% [markdown]
# #### 데이터 수집을 위한 기본 준비

# %%
# 필요한 모듈 참조

import requests
from bs4 import BeautifulSoup

# %%
# 웹 페이지 접속에 필요한 헤더정보 구성

user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"
header_info = {'User-agent': user_agent, 'referer': None}

# %% [markdown]
# #### 데이터 수집하기

# %%
# 접근할 페이지 주소

content_url = "https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=105&oid=052&aid=0001591826"

# %%
# 데이터 가져오기

r = requests.get(content_url, headers=header_info)

# 결과 검사
if r.status_code != 200:
    # 에러코드와 에러메시지를 문자열로 구성
    err_msg = "%d %s 에러가 발생했습니다." % (r.status_code, r.reason)
    # 강제로 에러를 발생시킨다.
    raise Exception(err_msg)
    
r.encoding="euc-kr"
html = r.text

# 출력되는 양이 많음으로 주석
#html

# %% [markdown]
# #### 기사 본문 추출

# %%
# 추출할 영역의 CSS 선택자를 확인하여
# 기사의 본문을 추출

# 웹 페이지의 소스코드를 사용하여 HTML 분석 객체로 생성
soup = BeautifulSoup(html, 'html.parser')

# CSS 선택자를 활용하여 가져오기를 원하는 부분 지정
# -> "#id"값 형식으로 지정
selector = soup.select('#articleBodyContents')

# 결과 검사
if len(selector) == 0:
    # 에러코드와 에러메시지를 문자열로 구성
    err_msg = "지정된 선택자에 대해서 인식된 구조가 없습니다."
    # 강제로 에러를 발생시킨다.
    raise Exception(err_msg)

# 출력되는 양이 많음으로 주석
#selector

# %% [markdown]
# #### 추출한 본문 영역에서 텍스트만 추출하기

# %%
# 본문 영역에 대한 결과 얻기

item = selector[0]
# 출력되는 양이 많음으로 주석
#print(item)

# %%
# 불필요한 태그들 제거하기

for target in item.find_all(['script', 'span', 'a']):
    target.extract()

# 출력되는 양이 많음으로 주석
# print(item)

# %%
# <br> 태그를 개행문자로 지환하기

for target in item.find_all('br'):
    target.replace_with("\n")

# 출력되는 양이 매우 방대하므로 출력 결과 확인 후 주석 처리하여 다시 한번 실행하자 -> 출력결과 숨김
#print(item)

# %%
# 최종 텍스트 추출

# 텍스트를 추출하면서 불필요한 앞뒤 공백도 함께 제거한다.
news_content = item.text.strip()
#news_content

# %%
# 추출된 결과를 텍스트로 저장한다

with open("네이버뉴스.txt", "w", encoding="utf-8") as f:
    f.write(news_content)

# %% [markdown]
# ### 하나의 페이지에서 파생되는 하위 페이지 데이터 수집

# %% [markdown]
# #### 웹 페이지 데이터 수집을 위한 기본준비

# %%
import requests                     # -> 웹 페이지 요청 모듈
import os                           # -> 운영체제 기능 접근 모듈(내장모듈)
import datetime as dt               # -> 날짜 처리 모듈(내장모듈)
from bs4 import BeautifulSoup       # -> 웹 페이지 소스코드 분석 모듈

# %%
# 웹 페이지 접속에 필요한 헤더정보 구성

user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36"
header_info = {'User-agent': user_agent, 'referer': None}

# %%
# 수집된 기사들이 텍스트로 저장될 폴더 생성

# 뉴스 기사가 저장될 폴더이름 구성
datetime = dt.datetime.now().strftime("%y%m%d_%H%M%S")
dirname = "뉴스기사_%s" % datetime

# 뉴스기사를 텍스트 파일로 저장할 폴더 만들기
if not os.path.exists(dirname):
    os.mkdir(dirname)

# %% [markdown]
# #### 컨텐츠의 주소들을 수집하기

# %%
# 접근할 페이지 주소 (네이버 뉴스 메인)

content_url = "https://news.naver.com/"

# %%
# 네이버 뉴스 메인 소스코드 가져오기

r = requests.get(content_url, headers=header_info)

# 결과 검사
if r.status_code != 200:
    # 에러코드와 에러메시지를 문자열로 구성
    err_msg = "%d %s 에러가 발생했습니다." % (r.status_code, r.reason)
    # 강제로 에러를 발생시킨다.
    raise Exception(err_msg)
    
r.encoding="euc-kr"
html = r.text

# 출력되는 양이 많음으로 주석
#html

# %%
# 수집된 내용에서 기사 본문으로 이동하기위한 <a>태그 수집

# 웹 페이지의 소스코드를 사용하여 HTML 분석 객체 생성
soup = BeautifulSoup(html, 'html.parser')

# CSS 선택자를 활용하여 가져오기를 원하는 부분 지정
# -> 여러 개의 선택자를 사용해야 할 경우 콤마(,)로 구분
selector = soup.select('.hdline_flick_item > .lnk_hdline_main_article, .hdline_article_tit > .lnk_hdline_article, .mtype_img a, .m2list a, .list_text_inner > .list_tit')

# 결과 검사
if len(selector) == 0:
    # 에러코드와 에러메시지를 문자열로 구성
    err_msg = "지정된 선택자에 대해서 인식된 구조가 없습니다."
    # 강제로 에러를 발생시킨다.
    raise Exception(err_msg)

#print(len(selector))
#print("-" * 50)
#selector

# %%
# 수집한 <a>태그에서 URL만 추출하여 리스트 저장

# 뉴스기사의 본문 URL을 저장할 리스트
url_list = []

# 리스트의 원소들에 대한 반복 처리
for item in selector:
    # 각 원소(링크)에 속성들(attrs) 중에 href 속성이 있다면 그 값을 별도로 준비한 리스트에 추가
    if "href" in item.attrs:
        url_list.append(item['href'])

#url_list

# %%
# 앞 부분에 도메인이 제외된 경우 적용하기

for i, v in enumerate(url_list):
    if content_url not in v:
        url = content_url + v
        url_list[i] = url
        
#url_list

# %%
# 뉴스 본문 페이지가 아닌경우 제외처리

news_url_list = []

for url in url_list:
    if "read.naver" in url:
        news_url_list.append(url)
        
news_url_list
# Out:
# ['https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=366&aid=0000750403',
#  'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=104&oid=052&aid=0001620563',
#  'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=105&oid=018&aid=0004997544',
#  'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=277&aid=0004945283',
#  'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=100&oid=011&aid=0003943131',
#  'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=101&oid=421&aid=0005509297',
#  'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=104&oid=023&aid=0003630216',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=100&oid=366&aid=0000750437',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=100&oid=366&aid=0000750437',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=102&oid=082&aid=0001110176',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=102&oid=082&aid=0001110176',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004830946',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004830946',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=104&oid=003&aid=0010635630',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=104&oid=003&aid=0010635630',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=018&aid=0004997683',
#  'https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=018&aid=0004997683',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=032&aid=0003088563&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=025&aid=0003122579&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=001&aid=0012560831&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=052&aid=0001620604&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=437&aid=0000272390&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=082&aid=0001110157&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=011&aid=0003943147&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=028&aid=0002554586&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=023&aid=0003630173&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=214&aid=0001138845&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=015&aid=0004585011&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=215&aid=0000974791&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=018&aid=0004997437&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=008&aid=0004623468&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=036&aid=0000045162&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=030&aid=0002960280&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=020&aid=0003373057&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=022&aid=0003605000&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=469&aid=0000620491&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=016&aid=0001867805&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=081&aid=0003205201&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=079&aid=0003534962&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=003&aid=0010635082&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=047&aid=0002321476&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=009&aid=0004830864&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=421&aid=0005508841&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=057&aid=0001596548&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=056&aid=0011091824&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=346&aid=0000042987&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=422&aid=0000497274&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=005&aid=0001460601&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=366&aid=0000750390&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=006&aid=0000108971&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=094&aid=0000009270&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=449&aid=0000212521&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=002&aid=0002202315&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=029&aid=0002689584&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=448&aid=0000335275&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=277&aid=0004945402&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=014&aid=0004683170&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=055&aid=0000910775&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=031&aid=0000614469&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=374&aid=0000252604&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=092&aid=0002229191&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=119&aid=0002515719&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=088&aid=0000714365&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=021&aid=0002480026&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=293&aid=0000035759&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=087&aid=0000854081&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=138&aid=0002107739&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=629&aid=0000097721&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=007&aid=0000006848&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=607&aid=0000000837&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=053&aid=0000029410&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=417&aid=0000719733&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=308&aid=0000029171&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=243&aid=0000014873&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=310&aid=0000089482&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=640&aid=0000014575&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=584&aid=0000015290&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=586&aid=0000027350&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=123&aid=0002251351&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=262&aid=0000014655&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=044&aid=0000229599&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=050&aid=0000058174&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=024&aid=0000069851&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=296&aid=0000051055&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=037&aid=0000029470&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=033&aid=0000042898&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=127&aid=0000031384&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=296&aid=0000051055&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=037&aid=0000029470&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=033&aid=0000042898&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=127&aid=0000031384&rankingType=RANKING',
#  'https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=648&aid=0000002683&rankingType=RANKING']

# %% [markdown]
# #### 뉴스 기사들에 대한 본문 수집

# %% [markdown]
# ##### 작업단계 나누기

# %%
# URL 목록만큼 반복
for i, url in enumerate(news_url_list):
        
    print("%d번째 뉴스기사 수집중... >> %s" % (i+1, url))
    
    #-------------------------------------------------
    # 1) 뉴스 상세 페이지에 접속하여 HTML 소스코드 가져오기
    #-------------------------------------------------
    r = requests.get(url, headers=header_info)

    # 접속에 실패했다면 다음 항목으로 반복문의 제어를 이동
    if r.status_code != 200:
        # 에러코드와 에러메시지를 문자열로 구성
        err_msg = "%d %s 에러가 발생했습니다." % (r.status_code, r.reason)
        print(err_msg)
        continue


    # 컨텐츠의 인코딩 형식 설정
    r.encoding = "euc-kr"

    
    #-------------------------------------------------
    # 2) 기사 영역 추출
    #-------------------------------------------------
    # HTML 코드 분석을 위한 객체 생성
    soup = BeautifulSoup(r.text, 'html.parser')

    
    #-------------------------------------------------
    # 3) 기사 영역에서 제목 추출
    #-------------------------------------------------
    title = soup.select("#articleTitle")
    #print(title)
    
    # 제목의 0번째 항목에서 텍스트를 공백 제거하고 추출
    title_str = title[0].text.strip()
    
    # 기사 제목에서 파일이름으로 사용할 수 없는 특수문자 제거
    title_str = title_str.replace("'", "")
    title_str = title_str.replace('"', "")
    title_str = title_str.replace("?", "")
    title_str = title_str.replace("/", "")
    title_str = title_str.replace(">", "")
    title_str = title_str.replace("<", "")
    
    # 둥근따옴표 제거
    # "`ㄴ`>한자" 입력후 표시되는 팝업에서 선택 가능함
    title_str = title_str.replace("‘", "") # `ㄴ`입력 후 `한자키` --> 1페이지에서 8번
    title_str = title_str.replace("’", "") # `ㄴ`입력 후 `한자키` --> 1페이지에서 9번
    title_str = title_str.replace("“", "") # `ㄴ`입력 후 `한자키` --> 2페이지에서 1번
    title_str = title_str.replace("”", "") # `ㄴ`입력 후 `한자키` --> 2페이지에서 2번
    
    print(title_str)

    
    #-------------------------------------------------
    # 4) 기사 영역에서 내용 추출
    #-------------------------------------------------
    # 본문 가져오기
    article = soup.select('#articleBodyContents')
    article_item = article[0]
    
    # 불필요한 태그 제거, 치환
    for target in article_item.find_all(['script', 'a', 'span']):
        target.extract()
        
    for target in article_item.find_all('br'):
        target.replace_with("\n")
    
    # 본문 텍스트 추출
    article_str = article_item.text.strip()

    
    #-------------------------------------------------
    # 5) 제목과 내용을 텍스트 파일로 저장
    #-------------------------------------------------
    # 제목과 내용이 모두 존재한다면?
    if title_str and article_str:
        # 기사 제목을 파일명으로 지정하여 내용을 텍스트로 저장한다.
        fname = dirname + "/" + title_str + ".txt"
        with open(fname, 'w', encoding='utf-8') as f:
            f.write(article_str)
            print(" >> 파일저장 성공: " + fname)
# Out:
# 1번째 뉴스기사 수집중... >> https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=366&aid=0000750403
# 이재용·전직 대통령 원포인트 사면....박범계 文, 그럴 분 아냐
#  >> 파일저장 성공: 뉴스기사_210729_112316/이재용·전직 대통령 원포인트 사면....박범계 文, 그럴 분 아냐.txt
# 2번째 뉴스기사 수집중... >> https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=104&oid=052&aid=0001620563
# 美 연방직원 접종 의무화...공화당 주지사들은 반발
#  >> 파일저장 성공: 뉴스기사_210729_112316/美 연방직원 접종 의무화...공화당 주지사들은 반발.txt
# 3번째 뉴스기사 수집중... >> https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=105&oid=018&aid=0004997544
# [속보] 넥슨 지주사 엔엑스씨, 이재교 신임 대표 선임
#  >> 파일저장 성공: 뉴스기사_210729_112316/[속보] 넥슨 지주사 엔엑스씨, 이재교 신임 대표 선임.txt
# 4번째 뉴스기사 수집중... >> https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=277&aid=0004945283
# 수세미로 발 닦던 방배동 족발집...더워서 그랬다더라
#  >> 파일저장 성공: 뉴스기사_210729_112316/수세미로 발 닦던 방배동 족발집...더워서 그랬다더라.txt
# 5번째 뉴스기사 수집중... >> https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=100&oid=011&aid=0003943131
# 치맥 회동 후 하락세 잦아든 윤석열 27.5% 1위···이재명 25.5%
#  >> 파일저장 성공: 뉴스기사_210729_112316/치맥 회동 후 하락세 잦아든 윤석열 27.5% 1위···이재명 25.5%.txt
# 6번째 뉴스기사 수집중... >> https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=101&oid=421&aid=0005509297
# 분조위 대신證 라임펀드, 80% 배상하라…불완전판매 결론
#  >> 파일저장 성공: 뉴스기사_210729_112316/분조위 대신證 라임펀드, 80% 배상하라…불완전판매 결론.txt
# 7번째 뉴스기사 수집중... >> https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=104&oid=023&aid=0003630216
# 美 연준 신중한 긴축 신호… 제로금리는 유지
#  >> 파일저장 성공: 뉴스기사_210729_112316/美 연준 신중한 긴축 신호… 제로금리는 유지.txt
# 8번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=100&oid=366&aid=0000750437
# 8000억 과징금 폭탄 위기 처한 해운업계…송영길 방안 찾겠다
#  >> 파일저장 성공: 뉴스기사_210729_112316/8000억 과징금 폭탄 위기 처한 해운업계…송영길 방안 찾겠다.txt
# 9번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=100&oid=366&aid=0000750437
# 8000억 과징금 폭탄 위기 처한 해운업계…송영길 방안 찾겠다
#  >> 파일저장 성공: 뉴스기사_210729_112316/8000억 과징금 폭탄 위기 처한 해운업계…송영길 방안 찾겠다.txt
# 10번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=102&oid=082&aid=0001110176
# 광안리 차 없는 문화의 거리, 코로나19 여파로 중단
#  >> 파일저장 성공: 뉴스기사_210729_112316/광안리 차 없는 문화의 거리, 코로나19 여파로 중단.txt
# 11번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=102&oid=082&aid=0001110176
# 광안리 차 없는 문화의 거리, 코로나19 여파로 중단
#  >> 파일저장 성공: 뉴스기사_210729_112316/광안리 차 없는 문화의 거리, 코로나19 여파로 중단.txt
# 12번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004830946
# 예천양조 측 무속인 영탁母, 돼지머리 묻으라 지시...가스라이팅 당해
#  >> 파일저장 성공: 뉴스기사_210729_112316/예천양조 측 무속인 영탁母, 돼지머리 묻으라 지시...가스라이팅 당해.txt
# 13번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=103&oid=009&aid=0004830946
# 예천양조 측 무속인 영탁母, 돼지머리 묻으라 지시...가스라이팅 당해
#  >> 파일저장 성공: 뉴스기사_210729_112316/예천양조 측 무속인 영탁母, 돼지머리 묻으라 지시...가스라이팅 당해.txt
# 14번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=104&oid=003&aid=0010635630
# 6호 태풍 인파 영향 지속…中, 열차운행 중단 등 피해 속출
#  >> 파일저장 성공: 뉴스기사_210729_112316/6호 태풍 인파 영향 지속…中, 열차운행 중단 등 피해 속출.txt
# 15번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=104&oid=003&aid=0010635630
# 6호 태풍 인파 영향 지속…中, 열차운행 중단 등 피해 속출
#  >> 파일저장 성공: 뉴스기사_210729_112316/6호 태풍 인파 영향 지속…中, 열차운행 중단 등 피해 속출.txt
# 16번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=018&aid=0004997683
# 김정주 창업자와 26년 인연…이재교, 넥슨 지주사 얼굴되다
#  >> 파일저장 성공: 뉴스기사_210729_112316/김정주 창업자와 26년 인연…이재교, 넥슨 지주사 얼굴되다.txt
# 17번째 뉴스기사 수집중... >> https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=105&oid=018&aid=0004997683
# 김정주 창업자와 26년 인연…이재교, 넥슨 지주사 얼굴되다
#  >> 파일저장 성공: 뉴스기사_210729_112316/김정주 창업자와 26년 인연…이재교, 넥슨 지주사 얼굴되다.txt
# 18번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=032&aid=0003088563&rankingType=RANKING
# 올림픽도 하는데 나만 왜···일본 시민들 인내심 바닥
#  >> 파일저장 성공: 뉴스기사_210729_112316/올림픽도 하는데 나만 왜···일본 시민들 인내심 바닥.txt
# 19번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=025&aid=0003122579&rankingType=RANKING
# 일주일만 슬퍼해줘 극단선택 아들의 부탁, 엄마는 거절했다
#  >> 파일저장 성공: 뉴스기사_210729_112316/일주일만 슬퍼해줘 극단선택 아들의 부탁, 엄마는 거절했다.txt
# 20번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=001&aid=0012560831&rankingType=RANKING
# [올림픽] 강백호, 축구 세리머니로 화답할까…김경문 놀랄 정도로 성장
#  >> 파일저장 성공: 뉴스기사_210729_112316/[올림픽] 강백호, 축구 세리머니로 화답할까…김경문 놀랄 정도로 성장.txt
# 21번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=052&aid=0001620604&rankingType=RANKING
# 금메달 반납해 도 넘은 비방에 안산 선수 메시지 확인 못 한다
#  >> 파일저장 성공: 뉴스기사_210729_112316/금메달 반납해 도 넘은 비방에 안산 선수 메시지 확인 못 한다.txt
# 22번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=437&aid=0000272390&rankingType=RANKING
# 김정환 넘어지자 조롱 독일선수 그게 아니라 직접 해명
#  >> 파일저장 성공: 뉴스기사_210729_112316/김정환 넘어지자 조롱 독일선수 그게 아니라 직접 해명.txt
# 23번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=082&aid=0001110157&rankingType=RANKING
# [속보] 확진자 속출… 유은혜 2학기 전면 등교, 8월 둘째 주까지 입장 발표
#  >> 파일저장 성공: 뉴스기사_210729_112316/[속보] 확진자 속출… 유은혜 2학기 전면 등교, 8월 둘째 주까지 입장 발표.txt
# 24번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=011&aid=0003943147&rankingType=RANKING
# 종로에 등장한 쥴리 벽화···김근식 옆에서 이재명 형수욕설 틀면 뭐라 할 건가
#  >> 파일저장 성공: 뉴스기사_210729_112316/종로에 등장한 쥴리 벽화···김근식 옆에서 이재명 형수욕설 틀면 뭐라 할 건가.txt
# 25번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=028&aid=0002554586&rankingType=RANKING
# 접종 6개월 뒤 효과, 화이자 84%…모더나 90%
#  >> 파일저장 성공: 뉴스기사_210729_112316/접종 6개월 뒤 효과, 화이자 84%…모더나 90%.txt
# 26번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=023&aid=0003630173&rankingType=RANKING
# 9억에 팔리던 집을 17억 주고 사버리네… 왕서방 아파트 쇼핑
#  >> 파일저장 성공: 뉴스기사_210729_112316/9억에 팔리던 집을 17억 주고 사버리네… 왕서방 아파트 쇼핑.txt
# 27번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=214&aid=0001138845&rankingType=RANKING
# 윤석열 27.5%, 이재명 25.5%, 이낙연 16.0%…최재형 5.5% [리얼미터]
#  >> 파일저장 성공: 뉴스기사_210729_112316/윤석열 27.5%, 이재명 25.5%, 이낙연 16.0%…최재형 5.5% [리얼미터].txt
# 28번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=015&aid=0004585011&rankingType=RANKING
# 안산 선수 금메달 박탈해야…페미니까 집단 테러 논란
#  >> 파일저장 성공: 뉴스기사_210729_112316/안산 선수 금메달 박탈해야…페미니까 집단 테러 논란.txt
# 29번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=215&aid=0000974791&rankingType=RANKING
# 모더나 백신 다시 공급…18~49세 접종 예정대로
#  >> 파일저장 성공: 뉴스기사_210729_112316/모더나 백신 다시 공급…18~49세 접종 예정대로.txt
# 30번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=018&aid=0004997437&rankingType=RANKING
# 최재형, 윤석열 아내 비방 벽화에 맹비판…더러운 폭력
#  >> 파일저장 성공: 뉴스기사_210729_112316/최재형, 윤석열 아내 비방 벽화에 맹비판…더러운 폭력.txt
# 31번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=008&aid=0004623468&rankingType=RANKING
# 친구 2명은 못 봤다는데 조국 딸 서울대서 봤다는 2+1명…누구
#  >> 파일저장 성공: 뉴스기사_210729_112316/친구 2명은 못 봤다는데 조국 딸 서울대서 봤다는 2+1명…누구.txt
# 32번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=036&aid=0000045162&rankingType=RANKING
# 왜 전화면접은 이재명, ARS는 윤석열이 강세
#  >> 파일저장 성공: 뉴스기사_210729_112316/왜 전화면접은 이재명, ARS는 윤석열이 강세.txt
# 33번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=030&aid=0002960280&rankingType=RANKING
# LG에너지솔루션, 현대차그룹과 인도네시아에 전기차 배터리 공장 세운다
#  >> 파일저장 성공: 뉴스기사_210729_112316/LG에너지솔루션, 현대차그룹과 인도네시아에 전기차 배터리 공장 세운다.txt
# 34번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=020&aid=0003373057&rankingType=RANKING
# 황선우, 반응속도 0.58초… 터보엔진 영법으로 초반 승부낸다
#  >> 파일저장 성공: 뉴스기사_210729_112316/황선우, 반응속도 0.58초… 터보엔진 영법으로 초반 승부낸다.txt
# 35번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=022&aid=0003605000&rankingType=RANKING
# 쥴리 벽화에 뱅크시급 친문 열광… 野 이재명 여배우 스캔들 벽화 그리면 뭐라 할까
#  >> 파일저장 성공: 뉴스기사_210729_112316/쥴리 벽화에 뱅크시급 친문 열광… 野 이재명 여배우 스캔들 벽화 그리면 뭐라 할까.txt
# 36번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=469&aid=0000620491&rankingType=RANKING
# 발로 센서 더듬기, 지루하고 납득도 안 돼 태권도 룰 비판 봇물
#  >> 파일저장 성공: 뉴스기사_210729_112316/발로 센서 더듬기, 지루하고 납득도 안 돼 태권도 룰 비판 봇물.txt
# 37번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=016&aid=0001867805&rankingType=RANKING
# 단골이예요~서비스 많이 배민에서 이런 거짓말 안 통한다
#  >> 파일저장 성공: 뉴스기사_210729_112316/단골이예요~서비스 많이 배민에서 이런 거짓말 안 통한다.txt
# 38번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=081&aid=0003205201&rankingType=RANKING
# 1박 2500만원 바흐 숙소…골판지침대 선수들과 딴판[김유민의돋보기]
#  >> 파일저장 성공: 뉴스기사_210729_112316/1박 2500만원 바흐 숙소…골판지침대 선수들과 딴판[김유민의돋보기].txt
# 39번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=079&aid=0003534962&rankingType=RANKING
# [속보]코로나19 신규확진 1674명…이틀 연속 1500명 웃돌아
#  >> 파일저장 성공: 뉴스기사_210729_112316/[속보]코로나19 신규확진 1674명…이틀 연속 1500명 웃돌아.txt
# 40번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=003&aid=0010635082&rankingType=RANKING
# [도쿄2020]안산을 지켜주세요…숏컷 페미 논란에 릴레이운동 확산
#  >> 파일저장 성공: 뉴스기사_210729_112316/[도쿄2020]안산을 지켜주세요…숏컷 페미 논란에 릴레이운동 확산.txt
# 41번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=047&aid=0002321476&rankingType=RANKING
# 부모님 먹거리 택배 엑셀로 정리하다 깜짝 놀란 지출 [오늘의 기사 제안]
#  >> 파일저장 성공: 뉴스기사_210729_112316/부모님 먹거리 택배 엑셀로 정리하다 깜짝 놀란 지출 [오늘의 기사 제안].txt
# 42번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=009&aid=0004830864&rankingType=RANKING
# 중화권 여배우 장백지 닮았다…중국 수구 선수 화제, 알고보니 과도한 보정
#  >> 파일저장 성공: 뉴스기사_210729_112316/중화권 여배우 장백지 닮았다…중국 수구 선수 화제, 알고보니 과도한 보정.txt
# 43번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=421&aid=0005508841&rankingType=RANKING
# 숨진 지 한달만에 발견된 20대 배달기사…취준생 방엔 이력서 100통
#  >> 파일저장 성공: 뉴스기사_210729_112316/숨진 지 한달만에 발견된 20대 배달기사…취준생 방엔 이력서 100통.txt
# 44번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=057&aid=0001596548&rankingType=RANKING
# 무 씻다 발 닦은 식당은 서울 족발집…위생상태 엉망
#  >> 파일저장 성공: 뉴스기사_210729_112316/무 씻다 발 닦은 식당은 서울 족발집…위생상태 엉망.txt
# 45번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=056&aid=0011091824&rankingType=RANKING
# 산책로서 사냥개 6마리의 습격…배경엔 우리 개는 안 물어요
#  >> 파일저장 성공: 뉴스기사_210729_112316/산책로서 사냥개 6마리의 습격…배경엔 우리 개는 안 물어요.txt
# 46번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=346&aid=0000042987&rankingType=RANKING
# 부앙~! 유달리 큰 방귀 소리… 의외의 원인 있다
#  >> 파일저장 성공: 뉴스기사_210729_112316/부앙~! 유달리 큰 방귀 소리… 의외의 원인 있다.txt
# 47번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=422&aid=0000497274&rankingType=RANKING
# [자막뉴스] 예뻐서 그래…지하철 안에서 성폭행 시도한 50대 구속 송치
#  >> 파일저장 성공: 뉴스기사_210729_112316/[자막뉴스] 예뻐서 그래…지하철 안에서 성폭행 시도한 50대 구속 송치.txt
# 48번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=005&aid=0001460601&rankingType=RANKING
# 아슬아슬…제주 중학생 살해 백광석, 극단선택前 검거
#  >> 파일저장 성공: 뉴스기사_210729_112316/아슬아슬…제주 중학생 살해 백광석, 극단선택前 검거.txt
# 49번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=366&aid=0000750390&rankingType=RANKING
# 코로나 신규 확진 1674명, 전방위 확산에 추가 대책 거론
#  >> 파일저장 성공: 뉴스기사_210729_112316/코로나 신규 확진 1674명, 전방위 확산에 추가 대책 거론.txt
# 50번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=006&aid=0000108971&rankingType=RANKING
# 이건희 성매매 동영상, 보도 가치 없다는 재판부
#  >> 파일저장 성공: 뉴스기사_210729_112316/이건희 성매매 동영상, 보도 가치 없다는 재판부.txt
# 51번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=094&aid=0000009270&rankingType=RANKING
# 클라이밍 대신 엉덩이 중계한 볼더링월드컵
#  >> 파일저장 성공: 뉴스기사_210729_112316/클라이밍 대신 엉덩이 중계한 볼더링월드컵.txt
# 52번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=449&aid=0000212521&rankingType=RANKING
# 日 올림픽 한창인데…확진자 9천 명 넘어 역대 최다
#  >> 파일저장 성공: 뉴스기사_210729_112316/日 올림픽 한창인데…확진자 9천 명 넘어 역대 최다.txt
# 53번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=002&aid=0002202315&rankingType=RANKING
# 학폭 신고만 7번...경희대는 왜 가해자를 입학시켰나
#  >> 파일저장 성공: 뉴스기사_210729_112316/학폭 신고만 7번...경희대는 왜 가해자를 입학시켰나.txt
# 54번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=029&aid=0002689584&rankingType=RANKING
# 김어준, 윤석열 부인 김건희 동거설에…치매 노모가 어떻게 개명 전 이름을 아나
#  >> 파일저장 성공: 뉴스기사_210729_112316/김어준, 윤석열 부인 김건희 동거설에…치매 노모가 어떻게 개명 전 이름을 아나.txt
# 55번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=448&aid=0000335275&rankingType=RANKING
# 박범계 광복절 원포인트 사면 文대통령 그런 분 아냐
#  >> 파일저장 성공: 뉴스기사_210729_112316/박범계 광복절 원포인트 사면 文대통령 그런 분 아냐.txt
# 56번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=277&aid=0004945402&rankingType=RANKING
# [속보] 임시 선별검사소서 436명 확진…수도권 372명-비수도권 64명
#  >> 파일저장 성공: 뉴스기사_210729_112316/[속보] 임시 선별검사소서 436명 확진…수도권 372명-비수도권 64명.txt
# 57번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=014&aid=0004683170&rankingType=RANKING
# 페미 안산 메달 반납해야 vs 선수 보호해야 갑론을박
#  >> 파일저장 성공: 뉴스기사_210729_112316/페미 안산 메달 반납해야 vs 선수 보호해야 갑론을박.txt
# 58번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=055&aid=0000910775&rankingType=RANKING
# 흉기 대며 성폭행 시도…지하철 1호선서 벌어진 일
#  >> 파일저장 성공: 뉴스기사_210729_112316/흉기 대며 성폭행 시도…지하철 1호선서 벌어진 일.txt
# 59번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=031&aid=0000614469&rankingType=RANKING
# 미성년 제자 성폭행 왕기춘 전 유도 국가대표 대법원 선고
#  >> 파일저장 성공: 뉴스기사_210729_112316/미성년 제자 성폭행 왕기춘 전 유도 국가대표 대법원 선고.txt
# 60번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=374&aid=0000252604&rankingType=RANKING
# [도쿄 올림픽] 양궁 김우진·강채영, 개인전 16강…안산·오진혁도 출전
#  >> 파일저장 성공: 뉴스기사_210729_112316/[도쿄 올림픽] 양궁 김우진·강채영, 개인전 16강…안산·오진혁도 출전.txt
# 61번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=092&aid=0002229191&rankingType=RANKING
# 화려한 우주 불꽃쇼…ISS 모듈 사라지다 [우주로 간다]
#  >> 파일저장 성공: 뉴스기사_210729_112316/화려한 우주 불꽃쇼…ISS 모듈 사라지다 [우주로 간다].txt
# 62번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=119&aid=0002515719&rankingType=RANKING
# 국민캠프 김병민 윤석열 8월말·9월초 입당하면 이준석 화나
#  >> 파일저장 성공: 뉴스기사_210729_112316/국민캠프 김병민 윤석열 8월말·9월초 입당하면 이준석 화나.txt
# 63번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=088&aid=0000714365&rankingType=RANKING
# 의료진·고교생 집단감염 등 대구 56명·경북 22명 신규확진…서문시장 총 6명(종합)
#  >> 파일저장 성공: 뉴스기사_210729_112316/의료진·고교생 집단감염 등 대구 56명·경북 22명 신규확진…서문시장 총 6명(종합).txt
# 64번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=021&aid=0002480026&rankingType=RANKING
# 그립습니다산골서 자라 먹은 적 없겠구나… 손수 소라 까주셨던 시아버지
#  >> 파일저장 성공: 뉴스기사_210729_112316/그립습니다산골서 자라 먹은 적 없겠구나… 손수 소라 까주셨던 시아버지.txt
# 65번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=293&aid=0000035759&rankingType=RANKING
# SKT, 고객 불만에 백기…할인형·적립형 중 멤버십 선택한다
#  >> 파일저장 성공: 뉴스기사_210729_112316/SKT, 고객 불만에 백기…할인형·적립형 중 멤버십 선택한다.txt
# 66번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=087&aid=0000854081&rankingType=RANKING
# [속보]라면값 줄줄이 오른다…신라면 내달 16일부터 7.6% 인상
#  >> 파일저장 성공: 뉴스기사_210729_112316/[속보]라면값 줄줄이 오른다…신라면 내달 16일부터 7.6% 인상.txt
# 67번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=138&aid=0002107739&rankingType=RANKING
# [속보] 삼성전자, 보통주·우선주 주당 361원 분기배당
#  >> 파일저장 성공: 뉴스기사_210729_112316/[속보] 삼성전자, 보통주·우선주 주당 361원 분기배당.txt
# 68번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=629&aid=0000097721&rankingType=RANKING
# 거리두기 4단계로 심각한데 대전시 방역행정 오락가락
#  >> 파일저장 성공: 뉴스기사_210729_112316/거리두기 4단계로 심각한데 대전시 방역행정 오락가락.txt
# 69번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=007&aid=0000006848&rankingType=RANKING
# 탈석탄 대규모 시민 캠페인, 의사결정은 어떻게
#  >> 파일저장 성공: 뉴스기사_210729_112316/탈석탄 대규모 시민 캠페인, 의사결정은 어떻게.txt
# 70번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=607&aid=0000000837&rankingType=RANKING
# 김영문 관세청장 · 손영배 부장검사에 밥 샀다 윤우진 스폰서 폭로 ②
#  >> 파일저장 성공: 뉴스기사_210729_112316/김영문 관세청장 · 손영배 부장검사에 밥 샀다 윤우진 스폰서 폭로 ②.txt
# 71번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=053&aid=0000029410&rankingType=RANKING
# 만성질환 부르는 염증 유발 음식, 이 다섯 가지는 줄이자
#  >> 파일저장 성공: 뉴스기사_210729_112316/만성질환 부르는 염증 유발 음식, 이 다섯 가지는 줄이자.txt
# 72번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=417&aid=0000719733&rankingType=RANKING
# 수도권 코로나 확진자 비율 65%… 신규 감염 1674명(상보)
#  >> 파일저장 성공: 뉴스기사_210729_112316/수도권 코로나 확진자 비율 65%… 신규 감염 1674명(상보).txt
# 73번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=308&aid=0000029171&rankingType=RANKING
# 좋은 게 좋은 거 전 한 번도 좋았던 적이 없는데요
#  >> 파일저장 성공: 뉴스기사_210729_112316/좋은 게 좋은 거 전 한 번도 좋았던 적이 없는데요.txt
# 74번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=243&aid=0000014873&rankingType=RANKING
# 백신만으론 역부족…코로나19 치료제 게임 체인저의 조건
#  >> 파일저장 성공: 뉴스기사_210729_112316/백신만으론 역부족…코로나19 치료제 게임 체인저의 조건.txt
# 75번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=310&aid=0000089482&rankingType=RANKING
# 한국 펜싱 남자 사브르 대표팀 금메달…올림픽 2연패
#  >> 파일저장 성공: 뉴스기사_210729_112316/한국 펜싱 남자 사브르 대표팀 금메달…올림픽 2연패.txt
# 76번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=640&aid=0000014575&rankingType=RANKING
# 2021.07.29 Cartoon
#  >> 파일저장 성공: 뉴스기사_210729_112316/2021.07.29 Cartoon.txt
# 77번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=584&aid=0000015290&rankingType=RANKING
# 치명률 떨어졌는데 델타변이 위험 과장주장에…전문가들 위험하지 않다 판단 일러
#  >> 파일저장 성공: 뉴스기사_210729_112316/치명률 떨어졌는데 델타변이 위험 과장주장에…전문가들 위험하지 않다 판단 일러.txt
# 78번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=586&aid=0000027350&rankingType=RANKING
# 무거운 삼전보다 가볍고 똘똘한 배터리주가 좋다
#  >> 파일저장 성공: 뉴스기사_210729_112316/무거운 삼전보다 가볍고 똘똘한 배터리주가 좋다.txt
# 79번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=123&aid=0002251351&rankingType=RANKING
# 내년부터 주민등록증 대신 스마트폰으로 신분 확인
#  >> 파일저장 성공: 뉴스기사_210729_112316/내년부터 주민등록증 대신 스마트폰으로 신분 확인.txt
# 80번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=262&aid=0000014655&rankingType=RANKING
# 강철부대 마스터 최영재 특전사 박군, SSU 황충원, UDT 정종현과 한 팀 하고파
#  >> 파일저장 성공: 뉴스기사_210729_112316/강철부대 마스터 최영재 특전사 박군, SSU 황충원, UDT 정종현과 한 팀 하고파.txt
# 81번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=044&aid=0000229599&rankingType=RANKING
# US welcomes restored inter-Korean hotlines
#  >> 파일저장 성공: 뉴스기사_210729_112316/US welcomes restored inter-Korean hotlines.txt
# 82번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=050&aid=0000058174&rankingType=RANKING
# 젝시믹스 글로벌 진출로 K애슬레저 선두 주자 될 것
#  >> 파일저장 성공: 뉴스기사_210729_112316/젝시믹스 글로벌 진출로 K애슬레저 선두 주자 될 것.txt
# 83번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=024&aid=0000069851&rankingType=RANKING
# 슈퍼 호황 골프노믹스…귀족 스포츠 옛말, 특수는 계속된다
#  >> 파일저장 성공: 뉴스기사_210729_112316/슈퍼 호황 골프노믹스…귀족 스포츠 옛말, 특수는 계속된다.txt
# 84번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=296&aid=0000051055&rankingType=RANKING
# 삶은 달걀 다이어트, 건강엔 괜찮을까
#  >> 파일저장 성공: 뉴스기사_210729_112316/삶은 달걀 다이어트, 건강엔 괜찮을까.txt
# 85번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=037&aid=0000029470&rankingType=RANKING
# 계열사 114개 카카오 왕국 나는 아직도 배고프다
#  >> 파일저장 성공: 뉴스기사_210729_112316/계열사 114개 카카오 왕국 나는 아직도 배고프다.txt
# 86번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=033&aid=0000042898&rankingType=RANKING
# [감옥에서 온 편지](3)법원의 선고보다 무서운 형벌
#  >> 파일저장 성공: 뉴스기사_210729_112316/[감옥에서 온 편지](3)법원의 선고보다 무서운 형벌.txt
# 87번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=127&aid=0000031384&rankingType=RANKING
# 최대 5배 배상 언론중재법, 8월 국회 처리 임박
#  >> 파일저장 성공: 뉴스기사_210729_112316/최대 5배 배상 언론중재법, 8월 국회 처리 임박.txt
# 88번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=296&aid=0000051055&rankingType=RANKING
# 삶은 달걀 다이어트, 건강엔 괜찮을까
#  >> 파일저장 성공: 뉴스기사_210729_112316/삶은 달걀 다이어트, 건강엔 괜찮을까.txt
# 89번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=037&aid=0000029470&rankingType=RANKING
# 계열사 114개 카카오 왕국 나는 아직도 배고프다
#  >> 파일저장 성공: 뉴스기사_210729_112316/계열사 114개 카카오 왕국 나는 아직도 배고프다.txt
# 90번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=033&aid=0000042898&rankingType=RANKING
# [감옥에서 온 편지](3)법원의 선고보다 무서운 형벌
#  >> 파일저장 성공: 뉴스기사_210729_112316/[감옥에서 온 편지](3)법원의 선고보다 무서운 형벌.txt
# 91번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=127&aid=0000031384&rankingType=RANKING
# 최대 5배 배상 언론중재법, 8월 국회 처리 임박
#  >> 파일저장 성공: 뉴스기사_210729_112316/최대 5배 배상 언론중재법, 8월 국회 처리 임박.txt
# 92번째 뉴스기사 수집중... >> https://news.naver.com//main/ranking/read.naver?mode=LSD&mid=shm&sid1=001&oid=648&aid=0000002683&rankingType=RANKING
# 사전청약 스타트!
#  >> 파일저장 성공: 뉴스기사_210729_112316/사전청약 스타트!.txt
